# %% [markdown]
# # Advanced Publication-Quality Visualizations
#
# NYT/Bloomberg/FT-style interactive charts for financial analysis.

# %%
import sys
import os
sys.path.append(os.path.join(os.path.dirname(os.getcwd())))

from core.advanced_visualizations import PublicationCharts
from core.data_fetcher import DataFetcher
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Waterfall Chart

# %%
# Example: DCF valuation breakdown
dcf_data = {
    'Base Value': 1000,
    'Revenue Growth': 200,
    'Margin Improvement': 150,
    'Tax Benefits': 50,
    'Discount Rate': -100,
    'Final Value': 1300
}

fig = PublicationCharts.waterfall_chart(dcf_data, title="DCF Valuation Breakdown")
fig.show()
